# %% [markdown]
# <a href="https://colab.research.google.com/github/BongWonHee/toy_pythons/blob/main/C_loopWithCounter_while_bwh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1부터 5까지 숫자가 순서대로 나열되는 while명령어 활용 코드.
count = 1 # flowchert P_SKY 님 차트참조
while count < 6 : # count >= 5 를 변경하였습니다.
 print (count)
 count += 1 
print ("END")
# Out:
# 1
# 2
# 3
# 4
# 5
# END

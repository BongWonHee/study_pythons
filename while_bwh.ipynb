# %% [markdown]
# <a href="https://colab.research.google.com/github/BongWonHee/toy_pythons/blob/main/while_bwh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first = 1

# %%
while first < 4 :
  print(first)
  print ('in whiling')
  first = first + 1 # first += 1로 변경 가능하다.
print ('end')
# Out:
# 1
# in whiling
# 2
# in whiling
# 3
# in whiling
# end
